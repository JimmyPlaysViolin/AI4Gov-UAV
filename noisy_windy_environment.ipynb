# %% [markdown]
# <a href="https://colab.research.google.com/github/JimmyPlaysViolin/AI4Gov-UAV/blob/main/noisy_windy_environment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyflyt
# Out:
# Requirement already satisfied: pyflyt in /usr/local/lib/python3.11/dist-packages (0.29.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from pyflyt) (0.60.0)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.11/dist-packages (from pyflyt) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pyflyt) (1.16.0)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (from pyflyt) (1.2.0)
# Requirement already satisfied: pettingzoo in /usr/local/lib/python3.11/dist-packages (from pyflyt) (1.25.0)
# Requirement already satisfied: pybullet in /usr/local/lib/python3.11/dist-packages (from pyflyt) (3.2.7)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from pyflyt) (6.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium->pyflyt) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium->pyflyt) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium->pyflyt) (0.0.4)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->pyflyt) (0.43.0)

# %%
import gymnasium as gym
import numpy as np
from PyFlyt.core import Aviary
import PyFlyt.gym_envs
import matplotlib.pyplot as plt

# %%
# !pip3 install numpy==1.25.2
# Out:
# Requirement already satisfied: numpy==1.25.2 in /usr/local/lib/python3.11/dist-packages (1.25.2)

# %%
# !pip3 install stable_baselines3
# Out:
# Requirement already satisfied: stable_baselines3 in /usr/local/lib/python3.11/dist-packages (2.7.0)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.2.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.25.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.6.0+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.3.0,>=0.29.1->stable_baselines3) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.3.0,>=0.29.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3) (3.0.2)

# %%
from stable_baselines3 import DQN
from stable_baselines3 import PPO

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
class NoisyObservationEnv(gym.Env):
    def __init__(self, env, noise_scale=0.1):
        super().__init__()
        self.env = env
        self.observation_space = env.observation_space
        self.action_space = env.action_space
        self.noise_scale = noise_scale

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        obs = obs + np.random.normal(0, self.noise_scale, size=obs.shape) # Add gaussian noise
        return obs, reward, terminated, truncated, info

    def reset(self, **kwargs):
        return self.env.reset(**kwargs)

# %%
class WindDisturbanceEnv(gym.Env):
    def __init__(self, env, force_scale=1.0, disturb_prob=0.2):
        super().__init__()
        self.env = env
        self.observation_space = env.observation_space
        self.action_space = env.action_space
        self.force_scale = force_scale
        self.disturb_prob = disturb_prob

    def step(self, action):
        # Simulates wind pushing in a random direction
        if np.random.rand() < self.disturb_prob:
            action = self.action_space.sample()  # chooses a random action for the drone to complete/ simulates the jerking of drones in wind
        return self.env.step(action)

    def reset(self, **kwargs):
        return self.env.reset(**kwargs)

# %%
# !pip install swig
# !pip install "gymnasium[box2d]"
# Out:
# Requirement already satisfied: swig in /usr/local/lib/python3.11/dist-packages (4.3.1)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.11/dist-packages (1.2.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (4.3.1)

# %%
wind_levels = [0.0, 0.05, 0.1, 0.2, 0.3]
performance = []

for noise in wind_levels:
    print(f"\nTraining with noise level: {noise}")

    # create and wrap environment in varying levels
    base_env = gym.make("PyFlyt/QuadX-Hover-v4", render_mode=None)
    noisy_env = WindDisturbanceEnv(base_env, disturb_prob = noise)

    # training agent
    model = PPO("MlpPolicy", noisy_env, verbose=0)
    model.learn(total_timesteps=25000)
    model.save(f"ppo_noise_{noise:.2f}")
    # evaluating the model
    mean_reward, std_reward = evaluate_policy(model, noisy_env, n_eval_episodes=5)
    performance.append((noise, mean_reward))
    print(f"Noise: {noise}, Mean Reward: {mean_reward}")

# plotting performance vs noise results
noise_vals, rewards = zip(*performance)
plt.plot(noise_vals, rewards, marker='o')
plt.title("Noise vs. Performance")
plt.xlabel("Observation Noise Std Dev")
plt.ylabel("Mean Reward")
plt.grid(True)
plt.show()
# Out:
# Training with noise level: 0.0
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
#
#
#
#
#
#
# Noise: 0.0, Mean Reward: -73.57070897594095
#
# Training with noise level: 0.05
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Noise: 0.05, Mean Reward: -71.83776145651936
#
# Training with noise level: 0.1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Noise: 0.1, Mean Reward: -76.4777660112828
#
# Training with noise level: 0.2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Noise: 0.2, Mean Reward: -76.56647049561143
#
# Training with noise level: 0.3

# %%
# # create the original environment
# base_env = gym.make("PyFlyt/QuadX-Hover-v4")  # Example environment
# # wrap it with the noisy observation wrapper
# env = WindDisturbanceEnv(base_env, disturb_prob = .2)
# obs = env.reset()

# %%
# # now you can use the environment with the added observation noise
# obs = env.reset()
# for _ in range(100):
#   action = env.action_space.sample()
#   obs, reward, terminated, truncated, info = env.step(action)
#   print(reward)
#   if terminated or truncated:
#     obs, _ = env.reset()

# %%
# from stable_baselines3 import PPO
# model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# model.learn(total_timesteps=100000)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.9     |
# |    ep_rew_mean     | -81.1    |
# | time/              |          |
# |    fps             | 145      |
# |    iterations      | 1        |
# |    time_elapsed    | 14       |
# |    total_timesteps | 2048     |
# ---------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.2         |
# |    ep_rew_mean          | -80.8        |
# | time/                   |              |
# |    fps                  | 147          |
# |    iterations           | 2            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0078615695 |
# |    clip_fraction        | 0.0733       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.66        |
# |    explained_variance   | 0.00543      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.03e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0111      |
# |    std                  | 0.994        |
# |    value_loss           | 2.69e+03     |
# ------------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.5        |
# |    ep_rew_mean          | -82.6       |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 3           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010372445 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.64       |
# |    explained_variance   | 0.0942      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.987       |
# |    value_loss           | 2.21e+03    |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.5         |
# |    ep_rew_mean          | -84.7        |
# | time/                   |              |
# |    fps                  | 149          |
# |    iterations           | 4            |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0086416975 |
# |    clip_fraction        | 0.0738       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.61        |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 795          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0117      |
# |    std                  | 0.981        |
# |    value_loss           | 1.91e+03     |
# ------------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 37.6       |
# |    ep_rew_mean          | -83.9      |
# | time/                   |            |
# |    fps                  | 150        |
# |    iterations           | 5          |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00727729 |
# |    clip_fraction        | 0.0581     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.59      |
# |    explained_variance   | 0.0907     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 859        |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00951   |
# |    std                  | 0.976      |
# |    value_loss           | 1.65e+03   |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.8        |
# |    ep_rew_mean          | -85.4       |
# | time/                   |             |
# |    fps                  | 152         |
# |    iterations           | 6           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008350367 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.56       |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 502         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.967       |
# |    value_loss           | 1.35e+03    |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.3        |
# |    ep_rew_mean          | -87.7       |
# | time/                   |             |
# |    fps                  | 152         |
# |    iterations           | 7           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008331034 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 575         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.964       |
# |    value_loss           | 1.21e+03    |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 43.4         |
# |    ep_rew_mean          | -87.9        |
# | time/                   |              |
# |    fps                  | 152          |
# |    iterations           | 8            |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0076087816 |
# |    clip_fraction        | 0.0844       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.52        |
# |    explained_variance   | 0.314        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 518          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0128      |
# |    std                  | 0.961        |
# |    value_loss           | 1.06e+03     |
# ------------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.3        |
# |    ep_rew_mean          | -89.5       |
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 9           |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010489246 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.54       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 472         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.97        |
# |    value_loss           | 887         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.9        |
# |    ep_rew_mean          | -87.8       |
# | time/                   |             |
# |    fps                  | 154         |
# |    iterations           | 10          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007717369 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.53       |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 312         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.959       |
# |    value_loss           | 814         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.2        |
# |    ep_rew_mean          | -89.6       |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 11          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008521532 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.52       |
# |    explained_variance   | 0.42        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 356         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.965       |
# |    value_loss           | 631         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.6        |
# |    ep_rew_mean          | -93.1       |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 12          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009214166 |
# |    clip_fraction        | 0.0986      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.51       |
# |    explained_variance   | 0.436       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 315         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.954       |
# |    value_loss           | 625         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50.8       |
# |    ep_rew_mean          | -88.3      |
# | time/                   |            |
# |    fps                  | 157        |
# |    iterations           | 13         |
# |    time_elapsed         | 168        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00782669 |
# |    clip_fraction        | 0.0869     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.47      |
# |    explained_variance   | 0.384      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 264        |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0123    |
# |    std                  | 0.949      |
# |    value_loss           | 634        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.7        |
# |    ep_rew_mean          | -91.7       |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 14          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010601379 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.45       |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 183         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.945       |
# |    value_loss           | 382         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.8        |
# |    ep_rew_mean          | -95.2       |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 15          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007512547 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.43       |
# |    explained_variance   | 0.524       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 142         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.941       |
# |    value_loss           | 468         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.5        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 16          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009106126 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.4        |
# |    explained_variance   | 0.567       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 165         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.931       |
# |    value_loss           | 466         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 58.1         |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 161          |
# |    iterations           | 17           |
# |    time_elapsed         | 215          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0061555766 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.38        |
# |    explained_variance   | 0.59         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 182          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00953     |
# |    std                  | 0.93         |
# |    value_loss           | 421          |
# ------------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.1        |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 18          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007560906 |
# |    clip_fraction        | 0.0666      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.37       |
# |    explained_variance   | 0.625       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 123         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.927       |
# |    value_loss           | 376         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 63.5         |
# |    ep_rew_mean          | -115         |
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 19           |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0074048364 |
# |    clip_fraction        | 0.0601       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.35        |
# |    explained_variance   | 0.685        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 107          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00958     |
# |    std                  | 0.922        |
# |    value_loss           | 321          |
# ------------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.1        |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 20          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009006241 |
# |    clip_fraction        | 0.0873      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.35       |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.1        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.924       |
# |    value_loss           | 281         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60.7        |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 21          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.009111958 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.34       |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 108         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.918       |
# |    value_loss           | 231         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.9        |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 22          |
# |    time_elapsed         | 274         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009702127 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.3        |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 81.2        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.909       |
# |    value_loss           | 227         |
# ...
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009872675 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.06       |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 116         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.863       |
# |    value_loss           | 292         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 75.5       |
# |    ep_rew_mean          | -107       |
# | time/                   |            |
# |    fps                  | 168        |
# |    iterations           | 41         |
# |    time_elapsed         | 497        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.00938694 |
# |    clip_fraction        | 0.0799     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.04      |
# |    explained_variance   | 0.825      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 112        |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0124    |
# |    std                  | 0.858      |
# |    value_loss           | 223        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.3        |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 42          |
# |    time_elapsed         | 508         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.009494045 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.04       |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 104         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.859       |
# |    value_loss           | 219         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.9        |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 43          |
# |    time_elapsed         | 519         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009843459 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.02       |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 117         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.852       |
# |    value_loss           | 249         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.3        |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 44          |
# |    time_elapsed         | 530         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009099273 |
# |    clip_fraction        | 0.0719      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.01       |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 79.8        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.851       |
# |    value_loss           | 190         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.9        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 45          |
# |    time_elapsed         | 541         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011248928 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.01       |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 78.5        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.854       |
# |    value_loss           | 194         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 76.8       |
# |    ep_rew_mean          | -100       |
# | time/                   |            |
# |    fps                  | 170        |
# |    iterations           | 46         |
# |    time_elapsed         | 553        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.00998967 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.01      |
# |    explained_variance   | 0.851      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 83.3       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0171    |
# |    std                  | 0.851      |
# |    value_loss           | 246        |
# ----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78          |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 47          |
# |    time_elapsed         | 564         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010471867 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.99       |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.1        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 0.847       |
# |    value_loss           | 179         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.9        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 48          |
# |    time_elapsed         | 575         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010289563 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.98       |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.9        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 0.846       |
# |    value_loss           | 183         |
# -----------------------------------------
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.9        |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 49          |
# |    time_elapsed         | 586         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.008881424 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.96       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.9        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 0.841       |
# |    value_loss           | 167         |
# -----------------------------------------

# %%
# mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
# print(f"Mean reward: {mean_reward} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
#
#
#
#
#
#
#
#
#
#
#
# Mean reward: -65.36227559765102 +/- 18.297199358127273

# %%
performance = []

# %%
#env.render()
# .3 wind disturbance = Mean reward: -65.36227559765102 +/- 18.297199358127273

# %%
#wind environment data
# Training with noise level: 0.0


# Noise: 0.0, Mean Reward: -73.2433608725667

# Training with noise level: 0.05



# Noise: 0.05, Mean Reward: -71.67692965114256

# Training with noise level: 0.1



# Noise: 0.1, Mean Reward: -74.75786998979747

# Training with noise level: 0.2


# Noise: 0.2, Mean Reward: -77.9028786212206

# Training with noise level: 0.3


# Noise: 0.3, Mean Reward: -88.15445534883766
